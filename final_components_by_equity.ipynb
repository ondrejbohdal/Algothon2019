# %%
import pandas as pd
import os
import glob

# %%
# Access Components
credit_components = './selected_kpca_components'
sentiment_components = './selected_kpca_components'
nlp_components = './nlp_components'
nlp_components_processed = './nlp_components_processed'
adjacency_processed = './adjacency/adj_matrices'

def get_tickers_in_path(path):
    tickers = [path.split('/')[-1] for path in glob.glob(path + '/*')]
    available_tickers = [t.split('.')[0] for t in tickers]
    
    return available_tickers

# Define all tickers
available_tickers = get_tickers_in_path(credit_components)

# %%
# Interpolate sentiment data
# available_tickers
for ticker in ['AAPL']:
    ticker_sentiment = pd.read_csv(nlp_components + '/%s.csv' % ticker).iloc[:,1:]
    ticker_sentiment = ticker_sentiment.drop(columns='headline')

    expanded_ticker = [] 
    ticker_sentiment['firstCreated'] = pd.to_datetime(ticker_sentiment['firstCreated'])

    for i in range(ticker_sentiment.shape[0]-1):
        row = ticker_sentiment.iloc[i,:]
        date = ticker_sentiment.iloc[i,0]
        date_next = ticker_sentiment.iloc[i+1,0]

        multiple = (date_next - date).days
        dates = pd.date_range(start=date, periods=multiple, freq="1d")

        if multiple > 0:

            repeated_values = pd.concat([pd.DataFrame(ticker_sentiment.iloc[i, :]).T]*multiple)
            repeated_values.iloc[:,0] = dates
            expanded_ticker.append(repeated_values)
        else:
            expanded_ticker.append(pd.concat([pd.DataFrame(ticker_sentiment.iloc[i, :]).T]))

    interpolated_data = pd.concat(expanded_ticker)
    interpolated_data.to_csv(nlp_components_processed + '/%s.csv' % ticker)

# %%
# Operate on adjacency matrices
def get_matrix_years_in_path(path):
    tickers = [path.split('/')[-1] for path in glob.glob(path + '/*')]
    available_matrices = [t.split('_')[-1] for t in tickers]
    available_matrices = [t.split('.')[0] for t in available_matrices]
    
    return available_matrices

matrix_years = get_matrix_years_in_path(adjacency_processed)

def load_matrix(year):
    name = 'adj_matrix_%s' % str(year)
    path = adjacency_processed + '/' + name + '.csv'
    
    matrix = pd.read_csv(path)
    matrix = matrix.set_index('supplier_ticker')
    
    return matrix

# Load Matrices
matrices = {}

for year in matrix_years:
    matrices[year] = load_matrix(year)

# %%
def get_non_zero_weights(w):
    return w.T[w.T.iloc[:,0] > 0].T

def rescale_weights(x):
    y = x.copy()
    vals = (x.values / x.values.sum())
    y.iloc[0,:] = vals 
    return y

def get_supplier_weights(ticker,year):
    matrix = matrices[year]
    matrix_row = matrix[matrix.index == ticker]
    x_non_zero = get_non_zero_weights(matrix_row)
    x_norm = rescale_weights(x_non_zero)
    return x_norm

# %%
get_supplier_weights('AAPL', '2016')
# Out:
#                    600288      9984       BBY       DCM         S        VZ
# supplier_ticker
# AAPL             0.002869  0.137762  0.209921  0.167282  0.078721  0.403445

# %%
x_norm
# Out:
#                      9984       BBY       CHL       DCM        IM         S  \
# supplier_ticker
# AAPL             0.073145  0.098633  0.052246  0.088819  0.114795  0.041797
#
#                         T      TECD      TMUS        VZ
# supplier_ticker
# AAPL             0.177638  0.123044  0.036572  0.193312

# %%
x_norm
# Out:
#                      9984       BBY       CHL       DCM        IM         S  \
# supplier_ticker
# AAPL             0.073145  0.098633  0.052246  0.088819  0.114795  0.041797
#
#                         T      TECD      TMUS        VZ
# supplier_ticker
# AAPL             0.177638  0.123044  0.036572  0.193312

# %%
x_non_zero.sum(axis=1)
# Out:
# supplier_ticker
# AAPL    0.191401
# dtype: float64

# %%
def get_days_in_month(month):
    if month == 2:
        return 29
    else:
        if month % 2 == 0:
            return 31
        else:
            return 30

for ticker in available_tickers:
    expanded_ticker = []
    pca_data = pd.read_csv('./pca_out/%s.csv' % ticker)
    price_data = pd.DataFrame(pd.read_csv('./price_data/%s.csv' % ticker)[['Date','Adj_Close']])  
    pca_data['datepll'] = pd.to_datetime(pca_data['datepll'])
    price_data['Date'] = pd.to_datetime(price_data['Date'])

    for i in range(pca_data.shape[0]):
        row = pca_data.iloc[i,:]
        month = pca_data.iloc[i,0].month
        multiple = get_days_in_month(month)
        dates = pd.date_range(start=pca_data.iloc[i,0], periods=multiple, freq="1d")

        repeated_values = pd.concat([pd.DataFrame(pca_data.iloc[i, :]).T]*multiple)
        repeated_values.iloc[:,0] = dates

        expanded_ticker.append(repeated_values)


    interpolated_data = pd.concat(expanded_ticker)
    merged_data = interpolated_data.merge(price_data, how='inner', left_on='datepll', right_on='Date')
    merged_data = merged_data.drop(columns=['Date'])
    merged_data.to_csv('./interpolated_pca_data/%s.csv' % ticker)
# Out:
#      Unnamed: 0 firstCreated  \
# 0             0   2016-11-01
# 1             1   2016-11-02
# 2             2   2016-11-07
# 3             3   2016-11-09
# 4             4   2016-11-14
# 5             5   2016-11-15
# 6             6   2016-11-17
# 7             7   2016-11-21
# 8             8   2016-11-22
# 9             9   2016-11-28
# 10           10   2016-11-29
# 11           11   2016-11-30
# 12           12   2016-12-01
# 13           13   2016-12-03
# 14           14   2016-12-05
# 15           15   2016-12-06
# 16           16   2016-12-07
# 17           17   2016-12-13
# 18           18   2016-12-14
# 19           19   2016-12-15
# 20           20   2016-12-16
# 21           21   2016-12-19
# 22           22   2016-12-20
# 23           23   2016-12-21
# 24           24   2016-12-22
# 25           25   2016-12-29
# 26           26   2016-12-30
# 27           27   2017-01-04
# 28           28   2017-01-06
# 29           29   2017-01-09
# ..          ...          ...
# 326         326   2018-09-18
# 327         327   2018-09-19
# 328         328   2018-09-21
# 329         329   2018-09-22
# 330         330   2018-09-24
# 331         331   2018-09-25
# 332         332   2018-09-26
# 333         333   2018-09-27
# 334         334   2018-09-28
# 335         335   2018-09-30
# 336         336   2018-10-01
# 337         337   2018-10-02
# 338         338   2018-10-04
# 339         339   2018-10-05
# 340         340   2018-10-07
# 341         341   2018-10-08
# 342         342   2018-10-11
# 343         343   2018-10-12
# 344         344   2018-10-14
# 345         345   2018-10-15
# 346         346   2018-10-16
# 347         347   2018-10-17
# 348         348   2018-10-18
# 349         349   2018-10-19
# 350         350   2018-10-23
# 351         351   2018-10-24
# 352         352   2018-10-25
# 353         353   2018-10-27
# 354         354   2018-10-29
# 355         355   2018-10-30
#
#                                               headline  \
# 0    BUZZ-Apple flirts with worst session in two mo...
# 1    SCALES CORPORATION  -  ENTERED INTO AN AGREEME...
# 2    APPLE HOSPITALITY REIT INC QTRLY SHR $0.07;; N...
# 3    PROPOSED ISSUE: City of Apple Valley, MN, $148...
# 4    Apple stock extends losses after China warning...
# 5    Apple considering expansion into wearable glas...
# 6    Taiwan stocks rise; TSMC, Hon Hai track Apple ...
# 7    APPLE  STARTED DISPERSING ENGINEERS TO OTHER P...
# 8    BRIEF-Kcell board approves agreement with Appl...
# 9    ACCC PROPOSES TO DENY AUTHORISATION FOR BANKS ...
# 10   Former regulatory official seeks to take over ...
# 11      Cook ups Apple support for fight against AIDS
# 12   UPDATE 2-Fallen smartphone brand Nokia challen...
# 13   Apple shows ambition to get into self-driving ...
# 14     APPLE INC SHARES DOWN 1.4 PCT IN MORNING TRADE
# 15   SALES OF APPLE WATCH TO CONSUMERS SET RECORD D...
# 16   Discounts, advertising spur brisk Apple Watch ...
# 17   APPLE INC <AAPL.O> - WILL START DELIVERING AIR...
# 18   P: $147.97M City of Apple Valley, Minnesota Pi...
# 19   APPLE INC - ON DECEMBER 13, 2016, BOARD OF DIR...
# 20   Porsche racecar engineer joins Apple -Manager ...
# 21   BREAKINGVIEWS-Irish fight yesterday's tax war ...
# 22   Apple in talks with India to manufacture local...
# 23   ADVISORY-Alerts on Apple Inc wrongly coded to ...
# 24   Nokia files more patent suits against Apple;; ...
# 25   MEDIA-Indian officials to assess incentives re...
# 26   APPLE INC SHARES DOWN 0.5 PCT AFTER NIKKEI REP...
# 27   APPLE: SOFTBANK VISION FUND WILL SUPPORT "STRA...
# 28   Canada's competition watchdog closes two-year ...
# 29   BUZZ-Apple: 10 years after the iPhone ;; BUZZ-...
# ..                                                 ...
# 326  Reuters Insider - Apple, Amazon lead Wall Stre...
# 327  APPLE HOSPITALITY REIT PROVIDES HURRICANE FLOR...
# 328  Reuters Insider - Apple embraces China with a ...
# 329  MEDIA-Apple seeks TV success without sex, viol...
# 330  BRIEF-Apple Acquires Shazam;; Apple completes ...
# 331  Qualcomm accuses Apple of stealing its secrets...
# 332  GM's Cadillac to leave Big Apple, return to Mi...
# 333  US STOCKS-Apple leads broad Wall St rally ;; U...
# 334  U.S. RESEARCH ROUNDUP-Apple, Blucora, Omnicom ...
# 335  Reuters Insider - Bumper harvest leaves Polish...
# 336  Reuters Insider - Record harvest a problem for...
# 337  LITHIA MOTORS LAUNCHES APPLE BUSINESS CHAT;; B...
# 338  APPLE SHARES DOWN 1.1 PCT ;; Apple, Amazon den...
# 339  UK cyber security agency backs Apple, Amazon C...
# 340  Apple tells Congress it found no signs of hack...
# 341  Reuters Insider - Apple says no signs of hacki...
# 342  DGAP-ADHOC:  DIALOG SEMICONDUCTOR AND APPLE EN...
# 343                           APPLE SHARES UP 3.4 PCT
# 344  APPLE ACQUIRES MUSIC ANALYTICS STARTUP ASAII -...
# 345  ZIMMER BIOMET - CO & APPLE COLLABORATE TO LAUN...
# 346  Nikkei heavyweight shares rebound but Apple su...
# 347  BREAKINGVIEWS-Finance makes Apple and Google f...
# 348  APPLE ANNOUNCES OCTOBER 30 EVENT - CNBC ;; BRI...
# 349  BUZZ-Apple: Wedbush starts with 'outperform';;...
# 350  MEDIA-Apple working on self-driving car 'pelot...
# 351  APPLE HOSPITALITY REIT PROVIDES HURRICANE MICH...
# 352     MEDIA-Apple News hits 90 million readers - NYT
# 353  Qualcomm says Apple $7 bln behind in royalty p...
# 354  BUZZ-Apple: Jefferies sees long-term opportuni...
# 355  APPLE SAYS IPAD PROS INCLUDE APPLE-DESIGNED A1...
#
#      compound_sentiment_value
# 0                     -0.9517
# 1                      0.6408
# 2                      0.2960
# 3                      0.0000
# 4                     -0.8020
# 5                      0.0000
# 6                      0.2960
# 7                     -0.6523
# 8                      0.7096
# 9                     -0.7626
# 10                     0.0000
# 11                     0.0258
# 12                     0.0772
# 13                     0.0000
# 14                     0.4466
# 15                     0.1613
# 16                     0.0516
# 17                    -0.3182
# 18                     0.0000
# 19                     0.6739
# 20                     0.3612
# 21                    -0.9371
# 22                     0.0000
# 23                    -0.1862
# 24                    -0.5719
# 25                     0.3182
# 26                    -0.2500
# 27                     0.8271
# 28                     0.0000
# 29                     0.0000
# ..                        ...
# 326                    0.0516
# 327                    0.0000
# 328                    0.0000
# 329                    0.7902
# 330                    0.0000
# 331                   -0.5267
# 332                   -0.0516
# 333                    0.3400
# 334                    0.5719
# 335                   -0.9509
# 336                   -0.6597
# 337                    0.0000
# 338                   -0.2185
# 339                    0.4404
# 340                   -0.6486
# 341                   -0.9694
# 342                    0.0000
# 343                    0.4466
# 344                    0.0000
# 345                    0.0000
# 346                    0.1531
# 347                    0.7184
# 348                    0.0000
# 349                    0.0000
# 350                    0.0000
# 351                   -0.6808
# 352                    0.0000
# 353                    0.0000
# 354                    0.3818
# 355                    0.0000
#
# [356 rows x 4 columns]
